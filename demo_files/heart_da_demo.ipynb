# %%
import os
# move cwd to /path/to/ROCCO
if os.getcwd().split('/')[-1] == 'demo_files':
    os.chdir('..')

# %% [markdown]
# # Differential Accessibility Testing with ROCCO
# In this notebook, we show how ROCCO can be used in differential accessibility studies. Note, the purpose of this document is not to identify biologically meaningful results, but to demonstrate a template for differential analysis.
#
# We compare tissue samples from two groups: `right` and `left` heart ventricle tissue samples, respectively.
#
# Each sample can be downloaded from ENCODE at
# ```
# https://www.encodeproject.org/files/[name]/@@download/[name]
# ```
# where `[name]` is replaced by an accession label in the first column of the table below
# e.g.,  `ENCFF670QFL`.
#
# ## Input and Preprocessing
#
# ### Sample Metadata
#
# We collect the following metadata in a tab-separated file, `heart_da_sampdata.txt`, that is conformable as `coldata` for DESeq2.
#
# There are $K_1=9$ `right` samples and $K_2=10$ `left` samples.
# ```
# name	group
# ENCFF056EAW	right
# ENCFF352HQI	right
# ENCFF580MBF	right
# ENCFF331WZQ	right
# ENCFF728DUT	right
# ENCFF219SJO	right
# ENCFF709NIR	right
# ENCFF836NAJ	right
# ENCFF658MBG	right
# ENCFF670QFL	left
# ENCFF456PVX	left
# ENCFF310VHO	left
# ENCFF097EXD	left
# ENCFF804KIW	left
# ENCFF420QMN	left
# ENCFF627RHW	left
# ENCFF771XJN	left
# ENCFF440WVI	left
# ENCFF704VYQ	left
# ```
#
# ### Generating signal tracks from BAM files
# With the BAM files for each sample available in the current working directory `/path/to/ROCCO`, we run
#
# ```
# python3 prep_bams.py --multi
# ```
#
# to create the necessary signal tracks for construction of $\mathbf{S}_{chr}$, the input matrix for ROCCO.
#
# Output wig files are divided by chromosome into directories `tracks_chr{}`.

# %% [markdown]
# ## Running ROCCO
#
# We run ROCCO on each group independently to produce two peak sets $P_{R}$ (right) and $P_{L}$ (left). We then merge these two peak sets to produce a final set $P_{R+L}$ to use for differential analysis. Splitting the groups in this way is optional.

# %% [markdown]
# We use the `--identifiers` parameter of ROCCO to specify a file containing tags/identifiers for each group in our sample. First, we generate the `--identifiers` files for each group from the sample metadata file:

# %%
# !cat demo_files/heart_da_sampdata.txt | grep right | cut -f1 > right.txt
# !cat demo_files/heart_da_sampdata.txt | grep left | cut -f1 > left.txt

# %% [markdown]
# We store the output files for each group in a separate directory using parameter `--outdir` and combine the resulting `ROCCO_out` bed files into a single group-specific bed file.
#
# For a lightweight demo, we restrict the experiment to three chromosomes, `chr18, chr19, chr20`:
#
# **da_demo_params.csv**
# ```
# chromosome,input_path,budget,gamma,tau,c1,c2,c3
# chr18,tracks_chr18,NULL,NULL,NULL,NULL,NULL,NULL
# chr19,tracks_chr19,NULL,NULL,NULL,NULL,NULL,NULL
# chr20,tracks_chr20,NULL,NULL,NULL,NULL,NULL,NULL
# ```
#
# Since each entry is NULL, default parameters will be used for each chromosome.

# %%
# !python3 ROCCO.py --outdir right --identifiers right.txt --combine right.bed -p demo_files/da_demo_params.csv --multi
# Out:
# cmd: python3 /work/users/n/h/nolanh/ROCCO/ROCCO_chrom.py --chrom chr18 --wig_path tracks_chr18 --budget 0.035 --gamma 1.0 --tau 0.0 --c1 1.0 --c2 1.0 --c3 1.0 --solver ECOS --bed_format 3 --outdir right --rr_iter 50
# retval: 0
#
# cmd: python3 /work/users/n/h/nolanh/ROCCO/ROCCO_chrom.py --chrom chr19 --wig_path tracks_chr19 --budget 0.035 --gamma 1.0 --tau 0.0 --c1 1.0 --c2 1.0 --c3 1.0 --solver ECOS --bed_format 3 --outdir right --rr_iter 50
# retval: 0
#
# cmd: python3 /work/users/n/h/nolanh/ROCCO/ROCCO_chrom.py --chrom chr20 --wig_path tracks_chr20 --budget 0.035 --gamma 1.0 --tau 0.0 --c1 1.0 --c2 1.0 --c3 1.0 --solver ECOS --bed_format 3 --outdir right --rr_iter 50
# retval: 0
#
# combining output files --> right.bed

# %%
# !python3 ROCCO.py --outdir left --identifiers left.txt --combine left.bed  -p demo_files/da_demo_params.csv --multi
# Out:
# cmd: python3 /work/users/n/h/nolanh/ROCCO/ROCCO_chrom.py --chrom chr18 --wig_path tracks_chr18 --budget 0.035 --gamma 1.0 --tau 0.0 --c1 1.0 --c2 1.0 --c3 1.0 --solver ECOS --bed_format 3 --outdir left --rr_iter 50
# retval: 0
#
# cmd: python3 /work/users/n/h/nolanh/ROCCO/ROCCO_chrom.py --chrom chr19 --wig_path tracks_chr19 --budget 0.035 --gamma 1.0 --tau 0.0 --c1 1.0 --c2 1.0 --c3 1.0 --solver ECOS --bed_format 3 --outdir left --rr_iter 50
# retval: 0
#
# cmd: python3 /work/users/n/h/nolanh/ROCCO/ROCCO_chrom.py --chrom chr20 --wig_path tracks_chr20 --budget 0.035 --gamma 1.0 --tau 0.0 --c1 1.0 --c2 1.0 --c3 1.0 --solver ECOS --bed_format 3 --outdir left --rr_iter 50
# retval: 0
#
# combining output files --> left.bed

# %% [markdown]
# ## Differential Analysis
# Now that we have peak files for both groups, we prepare input for the differential accessibility analysis
#
# ### Merge bed files from each group

# %%
# !cat right.bed left.bed | bedtools sort | bedtools merge > sorted_merged_right_left.bed

# %% [markdown]
# ### Create the count matrix
# `count_matrix.py` produces a sample-by-peak matrix with each element equal to the number of reads present in the respective sample alignment (row) in the peak region (column). It will sort the samples (rows) in the same order given in the sample metadata file `-m/--metadata`

# %%
# !python3 count_matrix.py -i sorted_merged_right_left.bed -m demo_files/heart_da_sampdata.txt -o right_left.tsv

# %%
import pandas as pd
count_df = pd.read_csv('right_left.tsv',sep="\t",index_col='name')
count_df
# Out:
# name             chr18_12900_13050  chr18_75900_75950  chr18_78400_78600  \
# ENCFF056EAW.bam                 54                  7                 29
# ENCFF352HQI.bam                 38                 21                 42
# ENCFF580MBF.bam                 13                  4                  2
# ENCFF331WZQ.bam                 29                 12                 32
# ENCFF728DUT.bam                 46                 13                 26
# ENCFF219SJO.bam                 27                 19                 18
# ENCFF709NIR.bam                 24                  4                 14
# ENCFF836NAJ.bam                  7                  5                  4
# ENCFF658MBG.bam                 85                 10                 35
# ENCFF670QFL.bam                 15                  5                 24
# ENCFF456PVX.bam                  5                  6                  3
# ENCFF310VHO.bam                  4                  0                 10
# ENCFF097EXD.bam                  5                  0                 11
# ENCFF804KIW.bam                 35                 13                 19
# ENCFF420QMN.bam                 18                  7                 23
# ENCFF627RHW.bam                 42                 11                 57
# ENCFF771XJN.bam                  6                  2                  8
# ENCFF440WVI.bam                 46                 14                 34
# ENCFF704VYQ.bam                 11                  7                 10
#
# name             chr18_85850_85900  chr18_95650_95950  chr18_96400_96500  \
# ENCFF056EAW.bam                 12                 35                 13
# ENCFF352HQI.bam                 16                 28                 23
# ENCFF580MBF.bam                  4                  7                  5
# ENCFF331WZQ.bam                 16                 45                 12
# ENCFF728DUT.bam                 16                 37                  7
# ENCFF219SJO.bam                 15                 39                 14
# ENCFF709NIR.bam                  9                 25                 15
# ENCFF836NAJ.bam                  4                  4                  1
# ENCFF658MBG.bam                 20                 40                 12
# ENCFF670QFL.bam                  8                 22                 15
# ENCFF456PVX.bam                  1                  5                  3
# ENCFF310VHO.bam                  0                 17                  8
# ENCFF097EXD.bam                  2                 17                  8
# ENCFF804KIW.bam                  4                 22                  7
# ENCFF420QMN.bam                 13                 25                 16
# ENCFF627RHW.bam                 21                 58                 19
# ENCFF771XJN.bam                  1                  6                  3
# ENCFF440WVI.bam                 21                 41                 32
# ENCFF704VYQ.bam                  7                 27                 12
#
# name             chr18_106450_111200  chr18_111300_112600  \
# ENCFF056EAW.bam                 1898                  401
# ENCFF352HQI.bam                 2152                  325
# ENCFF580MBF.bam                  778                  147
# ENCFF331WZQ.bam                 2215                  185
# ENCFF728DUT.bam                 2863                  318
# ENCFF219SJO.bam                 1662                  293
# ENCFF709NIR.bam                 1874                  212
# ENCFF836NAJ.bam                  590                   89
# ENCFF658MBG.bam                 3640                  342
# ENCFF670QFL.bam                 1390                  171
# ENCFF456PVX.bam                  283                   78
# ENCFF310VHO.bam                  421                   50
# ENCFF097EXD.bam                  610                   69
# ENCFF804KIW.bam                 1428                  205
# ENCFF420QMN.bam                 1980                  172
# ENCFF627RHW.bam                 3889                  319
# ENCFF771XJN.bam                  604                   59
# ENCFF440WVI.bam                 2225                  271
# ENCFF704VYQ.bam                  882                  162
#
# name             chr18_112800_112950  chr18_158000_159600  ...  \
# ENCFF056EAW.bam                   14                 3037  ...
# ENCFF352HQI.bam                   26                 1901  ...
# ENCFF580MBF.bam                    5                  742  ...
# ENCFF331WZQ.bam                   11                 1257  ...
# ENCFF728DUT.bam                   15                 1268  ...
# ENCFF219SJO.bam                   22                 1779  ...
# ENCFF709NIR.bam                   13                 1142  ...
# ENCFF836NAJ.bam                    5                  954  ...
# ENCFF658MBG.bam                   14                 2011  ...
# ENCFF670QFL.bam                    4                  697  ...
# ENCFF456PVX.bam                    3                  650  ...
# ENCFF310VHO.bam                    9                  215  ...
# ENCFF097EXD.bam                    9                  213  ...
# ENCFF804KIW.bam                   12                 1568  ...
# ENCFF420QMN.bam                   10                  917  ...
# ENCFF627RHW.bam                   18                 1290  ...
# ENCFF771XJN.bam                    8                  311  ...
# ENCFF440WVI.bam                   27                 1981  ...
# ENCFF704VYQ.bam                   10                  893  ...
#
# name             chr20_64262200_64262250  chr20_64262500_64262550  \
# ENCFF056EAW.bam                       17                       22
# ENCFF352HQI.bam                       23                       35
# ENCFF580MBF.bam                        7                        8
# ENCFF331WZQ.bam                       32                       48
# ENCFF728DUT.bam                       20                       33
# ENCFF219SJO.bam                       27                       46
# ENCFF709NIR.bam                       27                       36
# ENCFF836NAJ.bam                        4                        9
# ENCFF658MBG.bam                       21                       27
# ENCFF670QFL.bam                        6                       12
# ENCFF456PVX.bam                        7                        7
# ENCFF310VHO.bam                        3                        4
# ENCFF097EXD.bam                        4                        4
# ENCFF804KIW.bam                       15                       19
# ENCFF420QMN.bam                        4                       25
# ENCFF627RHW.bam                       13                       21
# ENCFF771XJN.bam                        8                       15
# ENCFF440WVI.bam                       29                       39
# ENCFF704VYQ.bam                       13                       18
#
# name             chr20_64262850_64263050  chr20_64263350_64263600  \
# ENCFF056EAW.bam                       57                       49
# ENCFF352HQI.bam                       58                       61
# ENCFF580MBF.bam                       17                        9
# ENCFF331WZQ.bam                       46                       43
# ENCFF728DUT.bam                       38                       44
# ENCFF219SJO.bam                       58                       47
# ENCFF709NIR.bam                       37                       41
# ENCFF836NAJ.bam                       13                       13
# ENCFF658MBG.bam                       69                       54
# ENCFF670QFL.bam                       21                       22
# ENCFF456PVX.bam                        7                       10
# ENCFF310VHO.bam                       15                        9
# ENCFF097EXD.bam                       15                        9
# ENCFF804KIW.bam                       54                       46
# ENCFF420QMN.bam                       35                       33
# ENCFF627RHW.bam                       32                       44
# ENCFF771XJN.bam                       16                       16
# ENCFF440WVI.bam                       54                       64
# ENCFF704VYQ.bam                       24                       25
#
# name             chr20_64265300_64265750  chr20_64267100_64267300  \
# ENCFF056EAW.bam                      112                       67
# ENCFF352HQI.bam                      113                       97
# ENCFF580MBF.bam                       14                       11
# ENCFF331WZQ.bam                       90                       81
# ENCFF728DUT.bam                       64                       70
# ENCFF219SJO.bam                       88                      107
# ENCFF709NIR.bam                       74                       83
# ENCFF836NAJ.bam                       28                       29
# ENCFF658MBG.bam                       76                       60
# ENCFF670QFL.bam                       73                       61
# ENCFF456PVX.bam                       30                       26
# ENCFF310VHO.bam                       17                        7
# ENCFF097EXD.bam                       17                        7
# ENCFF804KIW.bam                       95                       96
# ENCFF420QMN.bam                       90                       56
# ENCFF627RHW.bam                      110                       61
# ENCFF771XJN.bam                       57                       19
# ENCFF440WVI.bam                      144                      141
# ENCFF704VYQ.bam                       47                       37
#
# name             chr20_64267450_64267550  chr20_64268250_64268500  \
# ENCFF056EAW.bam                       18                      173
# ENCFF352HQI.bam                       27                      225
# ENCFF580MBF.bam                        3                       33
# ENCFF331WZQ.bam                       22                      123
# ENCFF728DUT.bam                       23                       76
# ENCFF219SJO.bam                       19                      175
# ENCFF709NIR.bam                       17                       95
# ENCFF836NAJ.bam                        5                       49
# ENCFF658MBG.bam                       22                       90
# ENCFF670QFL.bam                        8                       24
# ENCFF456PVX.bam                        4                       29
# ENCFF310VHO.bam                        1                        9
# ENCFF097EXD.bam                        1                        9
# ENCFF804KIW.bam                       20                      171
# ENCFF420QMN.bam                       10                       56
# ENCFF627RHW.bam                       15                      140
# ENCFF771XJN.bam                        5                       54
# ENCFF440WVI.bam                       32                      332
# ENCFF704VYQ.bam                        9                       67
#
# name             chr20_64285600_64286450  chr20_64327500_64327900
# ENCFF056EAW.bam                      649                      632
# ENCFF352HQI.bam                      677                      421
# ENCFF580MBF.bam                       88                      190
# ENCFF331WZQ.bam                      523                      218
# ENCFF728DUT.bam                      240                      169
# ENCFF219SJO.bam                      377                      313
# ENCFF709NIR.bam                      434                      111
# ENCFF836NAJ.bam                      126                      144
# ENCFF658MBG.bam                      885                      376
# ENCFF670QFL.bam                      200                      102
# ENCFF456PVX.bam                       54                      148
# ENCFF310VHO.bam                       51                       39
# ENCFF097EXD.bam                       57                       39
# ENCFF804KIW.bam                      593                      144
# ENCFF420QMN.bam                      276                      230
# ENCFF627RHW.bam                      430                      253
# ENCFF771XJN.bam                      106                       42
# ENCFF440WVI.bam                     1075                      278
# ENCFF704VYQ.bam                      193                      138
#
# [19 rows x 24414 columns]

# %% [markdown]
# Sample Metadata (coldata):

# %%
samp_df = pd.read_csv('demo_files/heart_da_sampdata.txt',sep="\t",index_col='name')
samp_df
# Out:
#                  group
# name
# ENCFF056EAW.bam  right
# ENCFF352HQI.bam  right
# ENCFF580MBF.bam  right
# ENCFF331WZQ.bam  right
# ENCFF728DUT.bam  right
# ENCFF219SJO.bam  right
# ENCFF709NIR.bam  right
# ENCFF836NAJ.bam  right
# ENCFF658MBG.bam  right
# ENCFF670QFL.bam   left
# ENCFF456PVX.bam   left
# ENCFF310VHO.bam   left
# ENCFF097EXD.bam   left
# ENCFF804KIW.bam   left
# ENCFF420QMN.bam   left
# ENCFF627RHW.bam   left
# ENCFF771XJN.bam   left
# ENCFF440WVI.bam   left
# ENCFF704VYQ.bam   left

# %% [markdown]
# ### Running DESeq2
#
# We use the PyDESeq2 package (`pip install pydeseq2`) to perform the differential analysis.

# %%
from pydeseq2.dds import DeseqDataSet
from pydeseq2.ds import DeseqStats
dds = DeseqDataSet(counts=count_df, clinical=samp_df, design_factors="group", n_cpus=8)
dds.deseq2()
# Out:
# Fitting size factors...
# ... done in 0.02 seconds.
#
# Fitting dispersions...
# ... done in 6.13 seconds.
#
# Fitting dispersion trend curve...
# ... done in 8.78 seconds.
#
# Fitting MAP dispersions...
# ... done in 6.37 seconds.
#
# Fitting LFCs...
# ... done in 3.50 seconds.
#
# Refitting 4 outliers.
#
# Fitting dispersions...
# ... done in 0.01 seconds.
#
# Fitting MAP dispersions...
# ... done in 0.01 seconds.
#
# Fitting LFCs...
# ... done in 0.01 seconds.

# %%
stat_res = DeseqStats(dds, n_cpus=8)
stat_res.summary()
# Out:
# Running Wald tests...
# ... done in 2.17 seconds.
#
# Log2 fold change & Wald test p-value: group right vs left
#                            baseMean  log2FoldChange     lfcSE      stat  \
# name
# chr18_12900_13050         19.750014        0.277859  0.266202  1.043788
# chr18_75900_75950          6.376229        0.002266  0.335083  0.006763
# chr18_78400_78600         18.363631       -0.726265  0.307226 -2.363948
# chr18_85850_85900          7.207599        0.042162  0.331515  0.127180
# chr18_95650_95950         24.546939       -0.695299  0.296028 -2.348761
# ...                             ...             ...       ...       ...
# chr20_64267100_64267300   45.348227       -0.273221  0.202428 -1.349720
# chr20_64267450_64267550    9.872817        0.056046  0.265466  0.211125
# chr20_64268250_64268500   73.247131       -0.132047  0.251459 -0.525123
# chr20_64285600_64286450  262.958460       -0.003051  0.227624 -0.013404
# chr20_64327500_64327900  175.821831        0.232639  0.265432  0.876456
#
#                            pvalue      padj
# name
# chr18_12900_13050        0.296584  0.735510
# chr18_75900_75950        0.994604       NaN
# chr18_78400_78600        0.018081  0.356926
# chr18_85850_85900        0.898798       NaN
# chr18_95650_95950        0.018836  0.363335
# ...                           ...       ...
# chr20_64267100_64267300  0.177106  0.645529
# chr20_64267450_64267550  0.832790       NaN
# chr20_64268250_64268500  0.599498  0.877299
# chr20_64285600_64286450  0.989306  0.997018
# chr20_64327500_64327900  0.380782  0.785425
#
# [24414 rows x 6 columns]

# %% [markdown]
# #### Differentially Accessible Peaks
# Using an FDR-corrected $p$-value threshold $\alpha=.05$, we find 42 differentially accessible peaks in `chr18-20` spanning roughly 15kb.

# %%
res_df = stat_res.results_df
da_peaks = res_df[res_df['padj'] < .05]
da_peaks
# Out:
#                            baseMean  log2FoldChange     lfcSE      stat  \
# name
# chr18_9505950_9506700     82.367298       -0.719543  0.162453 -4.429242
# chr18_12482050_12482300   30.580929       -0.808117  0.207305 -3.898204
# chr18_22113200_22113850  163.898494       -0.680514  0.174491 -3.899985
# chr18_23542050_23542250   19.606838       -0.935027  0.237387 -3.938823
# chr18_27619900_27620350  144.956233       -0.765002  0.172837 -4.426138
# chr18_29713350_29713550   19.732844       -0.906841  0.227723 -3.982205
# chr18_30679700_30679950   29.992442       -1.116671  0.252812 -4.417002
# chr18_31205000_31205100   22.222314       -0.841693  0.213436 -3.943537
# chr18_31213600_31213950   37.860407       -0.879928  0.227208 -3.872796
# chr18_31262300_31262550   32.313481       -1.065339  0.248812 -4.281707
# chr18_35782350_35782550   17.055254       -1.159843  0.292695 -3.962631
# chr18_46696200_46697100  163.933038       -0.680157  0.172702 -3.938334
# chr18_48355400_48355950   59.217255       -0.781490  0.200232 -3.902926
# chr18_48490700_48491200   54.781580       -0.826793  0.212559 -3.889708
# chr18_49514650_49515100   65.656325       -1.023715  0.201199 -5.088059
# chr18_58186650_58186950   39.794860       -0.735166  0.188693 -3.896090
# chr18_59333050_59333300   26.778379       -0.907203  0.221047 -4.104122
# chr18_59778550_59778850   38.530241       -1.332627  0.275413 -4.838652
# chr18_72847400_72847600   29.356431       -0.896651  0.219971 -4.076218
# chr18_73352600_73353050   79.230846       -0.913422  0.216531 -4.218443
# chr18_73402650_73403000   24.043951       -1.090602  0.244687 -4.457131
# chr18_75061450_75061650   18.629095       -1.035772  0.248851 -4.162210
# chr18_79542800_79544900  313.533267       -0.684458  0.160624 -4.261249
# chr18_79564850_79565200   33.685965       -0.951707  0.195466 -4.868924
# chr19_1170000_1170150     47.627432       -1.038510  0.257498 -4.033082
# chr19_7276400_7276550     44.547579       -1.078679  0.222512 -4.847744
# chr19_12440500_12440550   23.729780        0.846502  0.213357  3.967542
# chr19_22995100_22995200   24.525319       -1.086153  0.251388 -4.320622
# chr19_28967100_28967350   68.862348       -1.141175  0.242982 -4.696553
# chr19_38934500_38934700   60.802608       -0.930950  0.212738 -4.376043
# chr19_44149900_44149950   20.651515       -1.087683  0.264847 -4.106840
# chr19_46746250_46746300   16.956640        1.442259  0.319461  4.514664
# chr20_257550_257750       30.647221       -0.958245  0.224827 -4.262137
# chr20_14245750_14245950   45.637303       -1.016856  0.222693 -4.566170
# chr20_21151950_21152150   26.494069       -0.919762  0.217312 -4.232450
# chr20_21238550_21238750   43.624168       -0.760784  0.194342 -3.914661
# chr20_21661600_21661800   37.976728       -1.273681  0.242355 -5.255440
# chr20_21682550_21682800   34.149914       -1.076373  0.271490 -3.964683
# chr20_24359350_24359500   23.453069       -1.121746  0.274197 -4.091021
# chr20_25381000_25381300   42.362051       -0.772031  0.191687 -4.027559
# chr20_37160700_37160950   36.179463       -0.822786  0.212329 -3.875057
# chr20_64265300_64265750   60.290383       -0.708497  0.166971 -4.243244
#
#                                pvalue      padj
# name
# chr18_9505950_9506700    9.456485e-06  0.016018
# chr18_12482050_12482300  9.690895e-05  0.048145
# chr18_22113200_22113850  9.619853e-05  0.048145
# chr18_23542050_23542250  8.188240e-05  0.046351
# chr18_27619900_27620350  9.593506e-06  0.016018
# chr18_29713350_29713550  6.827885e-05  0.045928
# chr18_30679700_30679950  1.000791e-05  0.016018
# chr18_31205000_31205100  8.028845e-05  0.046351
# chr18_31213600_31213950  1.075940e-04  0.049204
# chr18_31262300_31262550  1.854652e-05  0.022968
# chr18_35782350_35782550  7.412834e-05  0.045928
# chr18_46696200_46697100  8.204930e-05  0.046351
# chr18_48355400_48355950  9.503679e-05  0.048145
# chr18_48490700_48491200  1.003649e-04  0.048193
# chr18_49514650_49515100  3.617460e-07  0.003474
# chr18_58186650_58186950  9.775821e-05  0.048145
# chr18_59333050_59333300  4.058538e-05  0.033892
# chr18_59778550_59778850  1.307229e-06  0.005022
# chr18_72847400_72847600  4.577413e-05  0.035167
# chr18_73352600_73353050  2.459955e-05  0.023624
# chr18_73402650_73403000  8.306369e-06  0.016018
# chr18_75061450_75061650  3.151824e-05  0.028827
# chr18_79542800_79544900  2.032875e-05  0.022968
# chr18_79564850_79565200  1.122078e-06  0.005022
# chr19_1170000_1170150    5.505014e-05  0.040092
# chr19_7276400_7276550    1.248734e-06  0.005022
# chr19_12440500_12440550  7.261758e-05  0.045928
# chr19_22995100_22995200  1.555902e-05  0.021346
# chr19_28967100_28967350  2.645888e-06  0.008470
# chr19_38934500_38934700  1.208531e-05  0.017856
# chr19_44149900_44149950  4.011095e-05  0.033892
# chr19_46746250_46746300  6.341725e-06  0.015226
# chr20_257550_257750      2.024814e-05  0.022968
# chr20_14245750_14245950  4.967160e-06  0.013629
# chr20_21151950_21152150  2.311594e-05  0.023368
# chr20_21238550_21238750  9.053140e-05  0.048145
# chr20_21661600_21661800  1.476707e-07  0.002836
# chr20_21682550_21682800  7.349345e-05  0.045928
# chr20_24359350_24359500  4.294782e-05  0.034371
# chr20_25381000_25381300  5.635900e-05  0.040092
# chr20_37160700_37160950  1.065996e-04  0.049204
# chr20_64265300_64265750  2.203115e-05  0.023368
